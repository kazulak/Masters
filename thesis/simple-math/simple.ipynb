# %%
SIZE = 8

# %%
host_array = [1, 2, 3, 4, 5, 6, 7, 128]
cache = host_array.copy()

for i in range(SIZE):
    cache[i] = cache[i] * 2 + 1

print(host_array)
print(cache)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 128]
# [3, 5, 7, 9, 11, 13, 15, 257]
