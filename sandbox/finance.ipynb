# %% [markdown]
# 66% w 4 lata - ile średnio rocznie to zysku

# %% [markdown]
# You are my thought, talking companion. You have to stay objecgtive and to the point.
#
#
#
# Context. I'm in relationship for nearly 10 years, we both have 25 years. I'm for vary long not to happy in the relationship. I tried many things (talking, trying to change behaviours, focusing on myself) but it didn't help me. I decided to break up - it's extreamly hard because of the 10 years together. I want to be as gentle as possible, and not suprice her. We recently talk and cried toghether and nearly broke up so she should know that it's possible. She will sleep in my apartment tonight and tomorrow we probably won't have time to meet and talk but the dey after I hope to meet her, talk and break up gently. I don't want to kiss her or hug to much tonight to not make her comfortable and then suprice with breakup but also it's bad moment for a breakup. I need strategy. How to act tonight, tomorrow, what messages to sent to make here know that we will break up, but gently.

# %% [markdown]
# Jesteś moim partnerem do myślenia i rozmowy. Musisz pozostać obiektywny i konkretny.
#
# Kontekst: Jestem w związku od prawie 10 lat, oboje mamy po 25 lat. Od bardzo dawna nie jestem w tym związku szczęśliwy. Próbowałem wielu rzeczy (rozmów, prób zmiany zachowań, skupienia się na sobie), ale to mi nie pomogło. Podjąłem decyzję o rozstaniu – to niezwykle trudne ze względu na te 10 wspólnych lat. Chcę być tak delikatny, jak to tylko możliwe, i jej nie zaskoczyć. Ostatnio rozmawialiśmy, płakaliśmy razem i prawie ze sobą zerwaliśmy, więc powinna zdawać sobie sprawę, że to możliwe.
#
# Wczoraj spała w moim mieszkaniu. Obeszło się bez całowania i gorącego przytulania, powiedziałem, że nie mam humoru. Dzisiaj odwiedziłem ją w kawiarni na 15 minut (pracuje jako baristka) nie będziemy mieli więcej czasu dzisiaj, żeby się spotkać i porozmawiać, ale jutro mam umówione spotkanie na 16:00 chcę wtedy porozmawiać i łagodnie zakończyć związek. Chcę ją uprzedzić, wysłać taką wiadomość, by wiedziała co się szykuje, ale zdecydowanie by nie było to zerwanie przez sms. Ona dzisiaj po 17:00 jest wolna, ja kończę zajęcia ok 18:00 i mam godzinę przerwy. Wtedy chcę wysłać tę wiadomość by miała wieczór u siebie i noc na oswojenie się z tą myślą o rozstaniu. Jest to dla mnie trudne rozstanie, bo nie ma jednego problemu, np. zdrady który by przeważył szalę, lecz jest to suma wszystkiego co składa się na to, że nie widzę się jako jej męża, a więc powinienem zakończyć ten związek. Parę miesięcy temu ustaliłem ze sobą, że jak do końca roku jej się nie oświadczę (bądź zaplanuję oświadczyny i będę ich pewny) to oznacza, że czas zakończyć związek, bo zbyt długo każdego dnia myślę o tym, że chyba powinniśmy się rozstać (już w sumie parę lat się tak męczę). Nie wiem czy powinienem w wiadomości dużo pisać. Nie wiem czy przy rozmowie mam się tłumaczyć, co mówić - trudno wytłumaczyć prosto moją decyzję właśnie z powodu tego, że jest to suma wielu lat a nie jakieś jedno wydarzenie co przechyliło szalę.
#
# Potrzebuję strategii. Jak mam się zachowywać jutro? Jakie wiadomości wysłać, żeby dać jej do zrozumienia, że się rozstaniemy, ale zrobić to łagodnie?

# %%
FINAL_GAIN = 66 # %
YEARS = 3 + 9/12

# %%
def calculate_yearly_gain(years, final_gain):
    return ((1 + final_gain / 100)**(1 / years) - 1) * 100

# %%
calculate_yearly_gain(YEARS, FINAL_GAIN)
# Out:
# 14.471003527322246

# %%
FINAL_GAIN = ((5*180-659)/659)*100
YEARS = 2 + 9/12
calculate_yearly_gain(YEARS, FINAL_GAIN)
# Out:
# 12.000706385313054

# %%
FINAL_GAIN = ((3*170-355.53)/355.53)*100
YEARS = 2 + 4/12
calculate_yearly_gain(YEARS, FINAL_GAIN)
# Out:
# 16.722488629734823
